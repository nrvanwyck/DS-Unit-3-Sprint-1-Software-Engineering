# %%
import lambdata_pkg_nrvanwyck as lambdata
import numpy as np
import pandas as pd

df = pd.DataFrame([[1, np.nan, 3], [3, 2, 1], [7, 8, np.nan]],
                  columns=['Washington', 'Adams', 'Jefferson'])

lambdata.null_checker(df)
# Out:
# (Washington    0
#  Adams         1
#  Jefferson     1
#  dtype: int64, <matplotlib.axes._subplots.AxesSubplot at 0x120f9cef0>)

# %%
y_test = [1, 2, 3]
y_pred = [1, 1, 3]

lambdata.plot_confusion_matrix(y_test, y_pred)
